# %%
# Imports
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Chapter 2 : Statistical Learning

# %% [markdown]
# ## Table of contents

# %% [markdown]
# - [Conceptual](#Conceptual)
#     - [Exercise 1](#Exercise-1)
#     - [Exercise 2](#Exercise-2)
#     - [Exercise 3](#Exercise-3)
#     - [Exercise 4](#Exercise-4)
#     - [Exercise 5](#Exercise-5)
#     - [Exercise 6](#Exercise-6)
#     - [Exercise 7](#Exercise-7)
# - [Applied](#Applied)
#     - [Exercise 8](#Exercise-8)
#     - [Exercise 9](#Exercise-9)
#     - [Exercise 10](#Exercise-10)

# %% [markdown]
#  ## Conceptual

# %% [markdown]
# ### Exercise 1
# [Table of contents](#Table-of-contents)

# %% [markdown]
# **Question.** For each parts (a) through (d), indicate whether we would generally expect the performance of a flexible statistical learning method to be better or worse than an inflexible method. Justify your answer.
#
# - (a)  The sample size n is extremely large, and the number of predictors p is small.
#
# - (b) The number of predictors p is extremely large, and the number of observations n is small.
#
# - (c) The relationship between the predictors and response is highly non-linear.
#
# - (d) The variance of the error terms, i.e. $σ^2 = Var(ε)$, is extremely high.
#
# **Answer.**
# - (a) A flexible model is better in this case because it can catch all the essence of the problem thanks to the large sample.
#
# - (b) An inflexible model is better here because a flexible model could easily overfit the training data.
#
# - (c) A flexible model because of the non-linearity of the problem.
#
# - (d) An inflexible model because the variance is extremely high. A flexible model will fit the noise in the error terms and increase variance.

# %% [markdown]
# ### Exercise 2
# [Table of contents](#Table-of-contents)

# %% [markdown]
# **Question.** Explain whether each scenario is a classification or regression problem, and indicate whether we are most interested in inference or prediction. Finally, provide n and p.
#
# - (a) We collect a set of data on the top 500 firms in the US. For each firm we record profit, number of employees, industry and the CEO salary. We are interested in understanding which factors affect CEO salary.
#
# - (b) We are considering launching a new product and wish to know whether it will be a success or a failure. We collect data on 20 similar products that were previously launched. For each product we have recorded whether it was a success or failure, price charged for the product, marketing budget, competition price, and ten other variables.
#
# - (c) We are interested in predicting the % change in the USD/Euro exchange rate in relation to the weekly changes in the world stock markets. Hence we collect weekly data for all of 2012. For each week we record the % change in the USD/Euro, the % change in the US market, the % change in the British market, and the % change in the German market.
#
# **Answer.**
#
# - (a) It is a regression problem, and we are interested in inference, as we want to know which factors influence a salary. Finally, $n = 500$ and $ p = 4 $.
#
# - (b) It is a classification problem, and we are interested in prediction because, given data on similar products, we want to predict whether the product failed. We have $ n=20$ and $p =13$.
#
# - (c) We are interested in prediction, but this can be a regression problem and a classification problem. We have $n= 52$ and $p = 4$.

# %% [markdown]
# ### Exercise 3
# [Table of contents](#Table-of-contents)

# %% [markdown]
# **Question.**
# - (a) Provide a sketch of typical (squared) bias, variance, training error, test error, and Bayes (or irreducible) error curves, on a single plot, as we go from less flexible statistical learning methods towards more flexible approaches. The x-axis should represent the amount of flexibility in the method, and the y-axis should represent the values for each curve. There should be five curves. Make sure to label each one.
#
# - (b) Explain why each of the five curves has the shape displayed in part (a).

# %% [markdown]
# **Answer.**
#
# - (a) ![chapter_2_exercise_3.png](attachment:chapter_2_exercise_3.png)
# - (b)
#     - Test MSE: it declines until we are not overfitting on the train set. Then our model will not generalize well anymore and therefore the test MSE will increase.
#     - Variance: it depends on the flexibility of the model. In fact, if a model is more flexible, then a small change in the training data will produce a higher error. Therefore, it monotonically increases.
#     - Irreducible error: it is a constant, so its curve will have a derivative equal to zero.
#     - Training MSE: it declines monotonically as flexibility increases. This is because we are overfitting on the train set.
#     - Squared bias: it decreases monotonically as we use more and more complex problems.

# %% [markdown]
# ### Exercise 4
# [Table of contents](#Table-of-contents)

# %% [markdown]
# **Question.** You will now think of some real-life applications for statistical learning.
# - (a) Describe three real-life applications in which classification might be useful. Describe the response, as well as the predictors. Is the goal of each application inference or prediction? Explain your answer.
# - (b) Describe three real-life applications in which regression might be useful. Describe the response, as well as the predictors. Is the goal of each application inference or prediction? Explain your answer.
# - (c) Describe three real-life applications in which cluster analysis might be useful.
#
# **Answer.**
# - (a)
#     - 1. Spam detector. A model which predicts if a mail is to be considered spam or not. This is a classification problem where the labels are spam and non-spam. We can use as a feature the mail that is considered spam and the ones that are not.
#     - 2. Edibile mushrooms detector. A model which predicts if a mushroom is edible or not. Therefore, the labels will be edible and non-edible. We can use as feature characteristics of the mushrooms.
#     - 3. University admission. We want to understand the factors that influence a student's admission to a university. This is a classification problem where we are interested in inference.
# - (b)
#     - 1. Price of gasoline. A model which will predict the price of gasoline for tomorrow. This is a prediction problem. We can use as a feature the price of the last two weeks.
#     - 2. Train dealy. A model which predicts if a train has a delay or not. We can use as features the historical data of delays of the trains as well as the weather and occupancy.
#     - 3. TV Sales. We want to understand if the money we used for TV-Spot will help us sell more TV. In this case, we have an inference problem.
# - (c)
#     - 1. Cancer type clustering. Diagnose cancer type more accurately.
#     - 2. Guess clustering. Understand which kind of guess our hotel as.
#     - 3. Spotify reccomandations. Recommend songs based on previously listed songs and other Users with similar music tastes.

# %% [markdown]
# ### Exercise 5
# [Table of contents](#Table-of-contents)

# %% [markdown]
# **Question.** What are the advantages and disadvantages of a very flexible (versus a less flexible) approach for regression or classification? Under what circumstances might a more flexible approach be preferred to a less flexible approach? When might a less flexible approach be preferred?
#
# **Answer.** A very flexible model can capture big non-linear problems. This means that we can approximate very complex problems in a good way. On the other hand, it is more challenging to interpret and has high variance. If we have a huge training set, it is better to use a highly flexible model. If not, better use a less flexible approach. A less flexible approach is preferred when we have small data and know that the problem is linear (or quite linear).

# %% [markdown]
# ### Exercise 6
# [Table of contents](#Table-of-contents)

# %% [markdown]
# ***Question.*** Describe the differences between a parametric and a non-parametric statistical learning approach. What are the advantages of a para- metric approach to regression or classification (as opposed to a non- parametric approach)? What are its disadvantages?
#
# ***Answer.***
# - A parametric approach reduces the problem of estimating f down to one of estimating a set of parameters because it assumes a form for f.
# - A non-parametric approach does not assume a patricular form of f and so requires a very large sample to accurately estimate f.
# - The advantages of a parametric approach to regression or classification are the simplifying of modeling f to a few parameters and not as many observations are required compared to a non-parametric approach.
# - The disadvantages of a parametric approach to regression or classification are a potentially inaccurate estimate f if the form of f assumed is wrong or to overfit the observations if more flexible models are used.

# %% [markdown]
# ### Exercise 7
# [Table of contents](#Table-of-contents)

# %% [markdown]
# **Question.** The table below provides a training data set containing six observa- tions, three predictors, and one qualitative response variable.

# %%
table = pd.DataFrame(data = {'X_1': [0,2,0,0,-1,1], 
                             'X_2': [3,0,1,1,0,1], 
                             'X_3': [0,0,3,2,1,1], 
                             'Y': ['Red','Red','Red','Green', 'Green', 'Red']}, 
                    index = [1,2,3,4,5,6])
display(table)
# Out:
#    X_1  X_2  X_3      Y
# 1    0    3    0    Red
# 2    2    0    0    Red
# 3    0    1    3    Red
# 4    0    1    2  Green
# 5   -1    0    1  Green
# 6    1    1    1    Red

# %% [markdown]
# Suppose we wish to use this data set to make a prediction for Y when $X_1 = X_2 = X_3 = 0$ using K-nearest neighbors.
# - (a) Compute the Euclidean distance between each observation and the test point, $X_1 = X_2 = X_3 = 0$
# - (b) What is our prediction with K = 1? Why?
# - (c) What is our prediction with K = 3? Why?
# - (d) If the Bayes decision boundary in this problem is highly non- linear, then would we expect the best value for K to be large or small? Why?

# %% [markdown]
# **Answer.**
# - (a) We have that:

# %%
for j in table.index:
    euclidian_distance = np.sum(np.array(table.loc[j])[:-1]**2)**0.5
    euclidian_distance = round(euclidian_distance, 2)
    print(f"The euclidian distance from observation {j} to the test point (0, 0, 0) is {euclidian_distance}.")
# Out:
# The euclidian distance from observation 1 to the test point (0, 0, 0) is 3.0.
# The euclidian distance from observation 2 to the test point (0, 0, 0) is 2.0.
# The euclidian distance from observation 3 to the test point (0, 0, 0) is 3.16.
# The euclidian distance from observation 4 to the test point (0, 0, 0) is 2.24.
# The euclidian distance from observation 5 to the test point (0, 0, 0) is 1.41.
# The euclidian distance from observation 6 to the test point (0, 0, 0) is 1.73.

# %% [markdown]
# - (b) The prediction will be Green ,because observation 5 is the closest to the test point.
# - (c) The prediction will be Red, becase we have three observation in the neighborhood of the test point and two of them are Red
# - (d) Small. A small K would give us a flexible bounduary, which is perfect for a non-linear problem.

# %% [markdown]
# ## Applied

# %% [markdown]
# ### Exercise 8
# [Table of contents](#Table-of-contents)

# %% [markdown]
#  - (a) Read the data

# %%
df_college = pd.read_csv('datasets/College.csv')
df_college = df_college.rename(columns={'Unnamed: 0': 'Name'})

# %% [markdown]
# - (b) Look at the data

# %%
df_college.head().transpose()
# Out:
#                                         0                   1               2  \
# Name         Abilene Christian University  Adelphi University  Adrian College
# Private                               Yes                 Yes             Yes
# Apps                                 1660                2186            1428
# Accept                               1232                1924            1097
# Enroll                                721                 512             336
# Top10perc                              23                  16              22
# Top25perc                              52                  29              50
# F.Undergrad                          2885                2683            1036
# P.Undergrad                           537                1227              99
# Outstate                             7440               12280           11250
# Room.Board                           3300                6450            3750
# ...

# %% [markdown]
# - (c)
#     - i. Numerical summary of the variables in the dataset.

# %%
df_college.describe().transpose()
# Out:
#              count          mean          std     min     25%     50%  \
# Apps         777.0   3001.638353  3870.201484    81.0   776.0  1558.0
# Accept       777.0   2018.804376  2451.113971    72.0   604.0  1110.0
# Enroll       777.0    779.972973   929.176190    35.0   242.0   434.0
# Top10perc    777.0     27.558559    17.640364     1.0    15.0    23.0
# Top25perc    777.0     55.796654    19.804778     9.0    41.0    54.0
# F.Undergrad  777.0   3699.907336  4850.420531   139.0   992.0  1707.0
# P.Undergrad  777.0    855.298584  1522.431887     1.0    95.0   353.0
# Outstate     777.0  10440.669241  4023.016484  2340.0  7320.0  9990.0
# Room.Board   777.0   4357.526384  1096.696416  1780.0  3597.0  4200.0
# Books        777.0    549.380952   165.105360    96.0   470.0   500.0
# Personal     777.0   1340.642214   677.071454   250.0   850.0  1200.0
# PhD          777.0     72.660232    16.328155     8.0    62.0    75.0
# ...

# %% [markdown]
# - (c)
#     - ii. Pairplot of the first ten columns or variables of the data

# %%
sns.pairplot(df_college.iloc[0:10 , 0: 10])

# %% [markdown]
# - (c)
#     - iii. boxplot of Outstate and Private

# %%
sns.set_theme(context='notebook', style='darkgrid', palette='deep', font='sans-serif', font_scale=1, color_codes=True, rc=None)#
sns.boxplot(data=df_college, x ='Outstate', y='Private')
# Out:
# <Axes: xlabel='Outstate', ylabel='Private'>

# %% [markdown]
# - (c)
#     - iv. Create a new qualitative variable, called Elite, by binning the Top10perc variable. We are going to divide universities into two groups based on whether or not the proportion of students coming from the top 10% of their high school classes exceeds 50 %. Then find how many elite univer- sities there are. Produce side-by-side boxplots of Outstate versus Elite.

# %%
# Creates new wualitative variable
df_college['Elite'] = df_college['Top10perc'].apply(lambda x: 'Yes' if x > 50 else 'No')

# Prints number of elite universities
print(f" There are {len(df_college[df_college.Elite == 'Yes'])} elite universities!")
      
# Plots
sns.set_theme(context='notebook', style='darkgrid', palette='deep', font='sans-serif', font_scale=1, color_codes=True, rc=None)#
sns.boxplot(data=df_college, x ='Outstate', y='Elite')
# Out:
#  There are 78 elite universities!
# <Axes: xlabel='Outstate', ylabel='Elite'>

# %% [markdown]
#  - (c)
#      - v. Produce some histograms with differing numbers of bins for a few of the quantitative variables.

# %%
fig, axs = plt.subplots(3, 3, sharex = False, sharey = False)
fig.set_size_inches(20, 10.5, forward=True)

g1 = sns.histplot(ax =axs[0,0],  data=df_college, x = 'Apps')
g2 = sns.histplot(ax =axs[0,1],  data=df_college, x = 'Accept')
g3 = sns.histplot(ax =axs[0,2],  data=df_college, x = 'Enroll')
g4 = sns.histplot(ax =axs[1,0],  data=df_college, x = 'Top10perc')
g5 = sns.histplot(ax =axs[1,1],  data=df_college, x = 'Top25perc')
g6 = sns.histplot(ax =axs[1,2],  data=df_college, x = 'F.Undergrad')
g7 = sns.histplot(ax =axs[2,0],  data=df_college, x = 'P.Undergrad')
g8 = sns.histplot(ax =axs[2,1],  data=df_college, x = 'Outstate')
g9 = sns.histplot(ax =axs[2,2],  data=df_college, x = 'Room.Board')

# %% [markdown]
# - (c)
#     - vi. Continue exploring the data, and provide a brief summary of what you discover.

# %% [markdown]
# We found that the max of the columns "Grad.Rate" and "PhD" are strictly bigger than 100. We have 118 and 103, respectively. This is problem as the two columns should represent percentage and so be less than 100.

# %% [markdown]
# ### Exercise 9
# [Table of contents](#Table-of-contents)

# %% [markdown]
# This exercise involves the Auto data set studied in the lab. Make sure that the missing values have been removed from the data.

# %%
df_auto = pd.read_csv('datasets/Auto.csv')
df_auto.horsepower = df_auto['horsepower'].replace({'?': df_auto.horsepower.min()} )
df_auto.horsepower = df_auto.horsepower.apply(lambda x: int(x))
df_auto.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0         130    3504          12.0    70
# 1  15.0          8         350.0         165    3693          11.5    70
# 2  18.0          8         318.0         150    3436          11.0    70
# 3  16.0          8         304.0         150    3433          12.0    70
# 4  17.0          8         302.0         140    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %% [markdown]
# - (a) Which of the predictors are quantitative, and which are qualitative?
#
# The quantitative predictiors are: mpg, cylinders, displacement, horsepower, weight, acceleration, year.
#
# The qualitative predictors are: origin, name.

# %% [markdown]
# - (b) What is the range of each quantitative predictor?

# %%
for p in ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'year']:
    
    print(f"The range of {p} is from {df_auto[p].min()} to {df_auto[p].max()}.")
# Out:
# The range of mpg is from 9.0 to 46.6.
# The range of cylinders is from 3 to 8.
# The range of displacement is from 68.0 to 455.0.
# The range of horsepower is from 46 to 230.
# The range of weight is from 1613 to 5140.
# The range of acceleration is from 8.0 to 24.8.
# The range of year is from 70 to 82.

# %% [markdown]
#  - (c) What is the mean and standard deviation of each quantitative predictor?

# %%
for p in ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'year']:
    
    print(f"The column {p} has mean {round(df_auto[p].mean(),2)} and standard deviation {round(df_auto[p].std(),2)}.")
# Out:
# The column mpg has mean 23.52 and standard deviation 7.83.
# The column cylinders has mean 5.46 and standard deviation 1.7.
# The column displacement has mean 193.53 and standard deviation 104.38.
# The column horsepower has mean 104.41 and standard deviation 38.25.
# The column weight has mean 2970.26 and standard deviation 847.9.
# The column acceleration has mean 15.56 and standard deviation 2.75.
# The column year has mean 75.99 and standard deviation 3.69.

# %% [markdown]
# - (d) Now remove the 10th through 85th observations. What is the range, mean, and standard deviation of each predictor in the subset of the data that remains?

# %%
df_r = df_auto.drop([10, 86, 1])
for p in ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'year']:
    
    print(f"The column {p} has mean {round(df_r[p].mean(),2)} and standard deviation {round(df_r[p].std(),2)}.")
# Out:
# The column mpg has mean 23.58 and standard deviation 7.82.
# The column cylinders has mean 5.44 and standard deviation 1.69.
# The column displacement has mean 192.37 and standard deviation 103.89.
# The column horsepower has mean 103.98 and standard deviation 38.06.
# The column weight has mean 2965.14 and standard deviation 849.07.
# The column acceleration has mean 15.59 and standard deviation 2.73.
# The column year has mean 76.03 and standard deviation 3.68.

# %% [markdown]
# - (e) Using the full data set, investigate the predictors graphically, using scatterplots or other tools of your choice. Create some plots highlighting the relationships among the predictors. Comment on your findings.

# %%
plt.title('Weight w.r.t. Horsepower')
sns.scatterplot(data= df_auto, x='weight', y='horsepower', hue='origin')
# Out:
# <Axes: title={'center': 'Weight w.r.t. Horsepower'}, xlabel='weight', ylabel='horsepower'>

# %% [markdown]
# In this graph we can see that the horsepower of an auto is dependent from its weight. Actually, we have the sentiment that a linear regression could describe well this dependency. Moreover, the autos coming from origin 1 are in general more heavier than the ones coming from origin 2 and 3. Consequently, autos from origin 1 also have more horsepower.

# %%
plt.title('Observations of mpg for year')
sns.stripplot(data=df_auto, x='year', y='mpg')
# Out:
# <Axes: title={'center': 'Observations of mpg for year'}, xlabel='year', ylabel='mpg'>

# %% [markdown]
# We can see that there is a shy increasing trend between the year of construction and the mpg.

# %% [markdown]
# - (f) Suppose that we wish to predict gas mileage (mpg) on the basis of the other variables. Do your plots suggest that any of the other variables might be useful in predicting mpg? Justify your answer.

# %%
plt.title('Relation between mpg, horsepower and cylinders')
sns.scatterplot(data=df_auto, x = 'horsepower', y='mpg', hue='cylinders')
# Out:
# <Axes: title={'center': 'Relation between mpg, horsepower and cylinders'}, xlabel='horsepower', ylabel='mpg'>

# %% [markdown]
# From the graph we can see that horsepower and cylinders are two good variables to predict mpg. In fact, the number of cylinders gives us a range for the mpg value, while the horsepower gives a trend.

# %% [markdown]
# ### Exercise 10
# [Table of contents](#Table-of-contents)

# %% [markdown]
# - (a) How many rows are in this data set? How many columns? What do the rows and columns represent?

# %%
df_boston = pd.read_csv('datasets/Boston.csv')
display(df_boston.head())
print(f'The dataset Boston.csv has {len(df_boston)} rows and {len(df_boston.columns)} columns.')
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2
# The dataset Boston.csv has 506 rows and 14 columns.

# %% [markdown]
# Boston.csv is a dataset containing housing values in 506 suburbs of Boston.
#
# Columns description:
# - crim: per capita crime rate by town.
# - zn: proportion of residential land zoned for lots over 25,000 sq.ft.
# - indus: proportion of non-retail business acres per town.
# - chas: Charles River dummy variable (= 1 if tract bounds river; 0 otherwise).
# - nox: nitrogen oxides concentration (parts per 10 million).
# - rm: average number of rooms per dwelling.
# - age: proportion of owner-occupied units built prior to 1940.
# - dis: weighted mean of distances to five Boston employment centres.
# - rad: index of accessibility to radial highways.
# - tax: full-value property-tax rate per 10000 USD.
# - ptratio: pupil-teacher ratio by town.
# - lstat: lower status of the population (percent).
# - medv: median value of owner-occupied homes in 1000 USD.

# %% [markdown]
# - (b) Make some pairwise scatterplots of the predictors (columns) in this data set. Describe your findings.

# %% [markdown]
# We found that _nox_ has a negative linear relationship with _dis_, and that _dis_ has a positive linear relationship with _medv_.

# %%
fig, axs = plt.subplots(1, 2, sharex = False, sharey = False)
fig.set_size_inches(20, 10.5, forward=True)

g1 = sns.regplot(ax =axs[0],  data = df_boston, x='nox', y='dis')
g2 = sns.regplot(ax =axs[1],  data = df_boston, x='dis', y='medv')

# %% [markdown]
# The relationships we found are not so surprising, in fact it is logical that if we move away from Boston's job centers then air quality increases and that near these centers the cost of property is higher.

# %% [markdown]
# - (c) Are any of the predictors associated with per capita crime rate? If so, explain the relationship.

# %% [markdown]
# The predictios associated with the capita crime rate doesn't seem to have a strong correlations with other variables. However, we have the following:

# %%
fig, axs = plt.subplots(4, 2, sharex = False, sharey = False)
fig.set_size_inches(20, 10.5, forward=True)

fig.suptitle('Relationships between crim and other variables', fontsize=20)

g1 = sns.regplot(ax =axs[0,0],  data = df_boston, x='crim', y='medv')
g2 = sns.regplot(ax =axs[0,1],  data = df_boston, x='crim', y='dis')
g3 = sns.regplot(ax =axs[1,0],  data = df_boston, x='crim', y='black')
g4 = sns.regplot(ax =axs[1,1],  data = df_boston, x='crim', y='indus')
g5 = sns.regplot(ax =axs[2,0],  data = df_boston, x='crim', y='nox')
g6 = sns.regplot(ax =axs[2,1],  data = df_boston, x='crim', y='rad')
g7 = sns.regplot(ax =axs[3,0],  data = df_boston, x='crim', y='tax')
fig.delaxes(axs[3,1])

# %% [markdown]
# We can see that the variables _crim_ has a positive linear relationship with _indus_, _nox_, _rad_ and _tax_, and a negative one with _medv_, _dis_ and _black_

# %% [markdown]
# - (d) Do any of the census tracts of Boston appear to have particularly high crime rates? Tax rates? Pupil-teacher ratios? Comment on the range of each predictor.

# %%
for c in ['crim', 'tax', 'ptratio']:
    print(f'The range of the predictor {c} goese from {df_boston[c].min()} to {df_boston[c].max()}.')
# Out:
# The range of the predictor crim goese from 0.00632 to 88.9762.
# The range of the predictor tax goese from 187 to 711.
# The range of the predictor ptratio goese from 12.6 to 22.0.

# %% [markdown]
# We can conclude that the there are Boston census tracts with an high crime rates/tax rates and pupil-teacher ratios. The crime rates is the one with the biggest range.

# %% [markdown]
# - (e) How many of the census tracts in this data set bound the Charles river?

# %%
print(f"There are {df_boston.chas.sum()} census tracts that bound the Charles river.")
# Out:
# There are 35 census tracts that bound the Charles river.

# %% [markdown]
# - (f) What is the median pupil-teacher ratio among the towns in this data set?

# %%
print(f"The median pupil-teacher ratio among the towns in the dataset is {df_boston.ptratio.median()}.")
# Out:
# The median pupil-teacher ratio among the towns in the dataset is 19.05.

# %% [markdown]
# - (g) Which census tract of Boston has lowest median value of owner- occupied homes? What are the values of the other predictors for that census tract, and how do those values compare to the overall ranges for those predictors? Comment on your findings.

# %%
print(f'The Boston census tract with the lowest median value of owner-occupied homes are the one with index {df_boston[df_boston.medv == df_boston.medv.min()].index.tolist()}.')
print('You can see this two census here:')
# Out:
# The Boston census tract with the lowest median value of owner-occupied homes are the one with index [398, 405].
# You can see this two census here:

# %%
df_boston[df_boston.medv == df_boston.medv.min()]
# Out:
#         crim   zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 398  38.3518  0.0   18.1     0  0.693  5.453  100.0  1.4896   24  666
# 405  67.9208  0.0   18.1     0  0.693  5.683  100.0  1.4254   24  666
#
#      ptratio   black  lstat  medv
# 398     20.2  396.90  30.59   5.0
# 405     20.2  384.97  22.98   5.0

# %% [markdown]
# We can see that these two census tracts have a high ratio of crime and of pupil pro teacher.

# %% [markdown]
# - (h) In this data set, how many of the census tracts average more than seven rooms per dwelling? More than eight rooms per dwelling? Comment on the census tracts that average more than eight rooms per dwelling.

# %%
print(f' There are {len(df_boston[df_boston.rm > 7])} Boston census tracts, that average more than seven rooms per dwelling and {len(df_boston[df_boston.rm > 8])}, that average more than eight.')
print('You can see displayed the 13 Boston census tracts with average of dwelling per room:')
# Out:
#  There are 64 Boston census tracts, that average more than seven rooms per dwelling and 13, that average more than eight.
# You can see displayed the 13 Boston census tracts with average of dwelling per room:

# %%
df_boston[df_boston.rm > 8]
# Out:
#         crim    zn  indus  chas     nox     rm   age     dis  rad  tax  \
# 97   0.12083   0.0   2.89     0  0.4450  8.069  76.0  3.4952    2  276
# 163  1.51902   0.0  19.58     1  0.6050  8.375  93.9  2.1620    5  403
# 204  0.02009  95.0   2.68     0  0.4161  8.034  31.9  5.1180    4  224
# 224  0.31533   0.0   6.20     0  0.5040  8.266  78.3  2.8944    8  307
# 225  0.52693   0.0   6.20     0  0.5040  8.725  83.0  2.8944    8  307
# 226  0.38214   0.0   6.20     0  0.5040  8.040  86.5  3.2157    8  307
# 232  0.57529   0.0   6.20     0  0.5070  8.337  73.3  3.8384    8  307
# 233  0.33147   0.0   6.20     0  0.5070  8.247  70.4  3.6519    8  307
# 253  0.36894  22.0   5.86     0  0.4310  8.259   8.4  8.9067    7  330
# 257  0.61154  20.0   3.97     0  0.6470  8.704  86.9  1.8010    5  264
# 262  0.52014  20.0   3.97     0  0.6470  8.398  91.5  2.2885    5  264
# 267  0.57834  20.0   3.97     0  0.5750  8.297  67.0  2.4216    5  264
# ...

# %% [markdown]
# we can see that these are neighborhoods where taxes are generally low. So middle/poor neighborhoods. They have a generally constant air pollution rate and also a _black_ predictor around 360/380.
